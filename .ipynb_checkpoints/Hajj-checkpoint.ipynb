# %%
import pandas as pd
import numpy as np

# %%
hajj_df = pd.read_csv('Hajj.csv')

# %%
hajj_df.head()
# Out:
#    Year   pilgrims
# 0  1999  1,839,154
# 1  2000  1,913,263
# 2  2001  1,944,760
# 3  2002  2,041,129
# 4  2003  2,012,074

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
hajj_df.plot(kind='line', 
             stacked=False,
             figsize=(20, 10), # pass a tuple (x, y) size
             )
